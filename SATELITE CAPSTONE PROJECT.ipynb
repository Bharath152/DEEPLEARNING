# %% [markdown]
# # SATELLITE IMAGE CLASSIFICATION CAPSTONE PROJECT

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from sklearn.utils import shuffle
from skimage.transform import resize
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
import glob
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read the file

# %%
cloudy=glob.glob('data/cloudy/*jpg')
desert=glob.glob('data/desert//*jpg')
green_area=glob.glob('data/green_area//*jpg')
water=glob.glob('data/water//*jpg')

# %% [markdown]
# ### Add the images into the list

# %%
classes={0:'cloudy',1:'desert',2:'green_area',3:'water'}

# %%
images = []
labels = []

for i in cloudy:
    img = plt.imread(i)
    images.append(img)
    labels.append(0)

for i in desert:
    img = plt.imread(i)
    images.append(img)
    labels.append(1)

for i in green_area:
    img = plt.imread(i)
    images.append(img)
    labels.append(2)

for i in water:
    img = plt.imread(i)
    images.append(img)
    labels.append(3)

# %%
len(cloudy)
# Out:
# 1500

# %%
len(desert)
# Out:
# 1131

# %%
len(green_area)
# Out:
# 1500

# %%
len(water)
# Out:
# 1500

# %% [markdown]
# ### plot some images

# %%
plt.figure(figsize=(8,8))
for i in  range(15):
    plt.subplot(5,3,i+1)
    plt.imshow(images[i])
    plt.title(classes[labels[i]])
plt.tight_layout()

# %% [markdown]
# ### shuffle the data

# %%
images,labels=shuffle(images,labels)

# %% [markdown]
# ### plot some images after shuffling

# %%
plt.figure(figsize=(8,8))
for i in  range(15):
    plt.subplot(5,3,i+1)
    plt.imshow(images[i])
    plt.title(classes[labels[i]])
plt.tight_layout()

# %% [markdown]
# ### Reshape the images

# %%
X = []

for i in images:
    X.append(resize(i, (64,64,3)))

# %% [markdown]
# ### Plot images after reshape

# %%
plt.figure(figsize=(10, 8))
for i in range(12):
    plt.subplot(4, 4, i+1)
    plt.imshow(X[i], cmap='gray')
    plt.title(classes[labels[i]])
plt.tight_layout()

# %% [markdown]
# ### Train the dataset

# %%
X = np.array(X)
y = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train.shape
# Out:
# (4504, 64, 64, 3)

# %%
y_train.shape
# Out:
# (4504,)

# %% [markdown]
# ### Add keras sequencial model with CNN

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (64, 64, 3)),
    keras.layers.MaxPool2D(2,2),
    
    keras.layers.Conv2D(32,(3,3), activation = 'relu'),
    keras.layers.MaxPool2D(2,2),
    
    keras.layers.Flatten(),
    
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dense(4, activation = 'sigmoid')
])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer = 'adam',loss='sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 62, 62, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 29, 29, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         401,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 406,820 (1.55 MB)
#  Trainable params: 406,820 (1.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %%
model.fit(X_train,y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6332 - loss: 0.7985 - val_accuracy: 0.9047 - val_loss: 0.2687
# Epoch 2/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8801 - loss: 0.2691 - val_accuracy: 0.8337 - val_loss: 0.3217
# Epoch 3/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8884 - loss: 0.2448 - val_accuracy: 0.9335 - val_loss: 0.1880
# Epoch 4/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9182 - loss: 0.1842 - val_accuracy: 0.9490 - val_loss: 0.1591
# Epoch 5/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9324 - loss: 0.1646 - val_accuracy: 0.8958 - val_loss: 0.2485
# Epoch 6/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9335 - loss: 0.1573 - val_accuracy: 0.9335 - val_loss: 0.1497
# Epoch 7/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9275 - loss: 0.1632 - val_accuracy: 0.9069 - val_loss: 0.2254
# Epoch 8/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9373 - loss: 0.1534 - val_accuracy: 0.9135 - val_loss: 0.1661
# Epoch 9/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9276 - loss: 0.1605 - val_accuracy: 0.9534 - val_loss: 0.1324
# Epoch 10/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9531 - loss: 0.1240 - val_accuracy: 0.9557 - val_loss: 0.1199

# %% [markdown]
# ### Eva;luate the model

# %%
model.evaluate(X_train, y_train)
# Out:
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9638 - loss: 0.0990
# [0.0995098277926445, 0.9646980166435242]

# %% [markdown]
# ### Predit the model

# %%
prediction = model.predict(X_test)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
pred = [np.argmax(i) for i in prediction]

# %%
plt.figure(figsize=(10, 8))
for i in range(12):
    plt.subplot(4, 4, i+1)
    plt.imshow(X_test[i], cmap='gray')
    plt.title(classes[pred[i]])
plt.tight_layout()

# %% [markdown]
# ### Accuracy score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9733806566104702

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(confusion_matrix(y_test,pred), annot = True,fmt='d')
plt.show()

# %% [markdown]
# ### Classification report

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       311
#            1       1.00      1.00      1.00       201
#            2       0.94      0.97      0.95       318
#            3       0.97      0.93      0.95       297
#
#     accuracy                           0.97      1127
#    macro avg       0.98      0.98      0.98      1127
# weighted avg       0.97      0.97      0.97      1127
